# %%
##### # Imports

# Pandas and numpy for data manipulation
import pandas as pd
import numpy as np
from random import randint

# No warnings about setting value on copy of slice
pd.options.mode.chained_assignment = None

# Display up to 60 columns of a dataframe
pd.set_option('display.max_columns', 60)

# Matplotlib visualization
import matplotlib.pyplot as plt
# %matplotlib inline

# Set default font size
plt.rcParams['font.size'] = 24

# Internal ipython tool for setting figure size
from IPython.core.pylabtools import figsize

# Seaborn for visualization
import seaborn as sns
sns.set(font_scale = 2)

# Splitting data into training and testing
from sklearn.model_selection import train_test_split

#Imputing missing values and scaling values
from sklearn.preprocessing import Imputer, MinMaxScaler

#Import scikit-learn metrics module for accuracy calculation
from sklearn import metrics

#Machine Learning Models
from sklearn.ensemble import RandomForestClassifier
from sklearn.linear_model import LinearRegression
from sklearn.ensemble import RandomForestRegressor, GradientBoostingRegressor
from sklearn.svm import SVR
from sklearn.neighbors import KNeighborsRegressor
#from xgboost import XGBRegressor


# Hyperparameter tuning
from sklearn.model_selection import RandomizedSearchCV, GridSearchCV

# %%
raw_df = pd.read_csv('processed/df_sorted.csv', parse_dates=["issue_d", "last_pymnt_d"]) #read training data

# %%
raw_df.head()
# Out:
#    loan_amnt  funded_amnt  funded_amnt_inv        term  int_rate  installment  \
# 0      13000        13000     11525.000000   36 months    0.1062       423.28
# 1       7000         7000      6785.947887   36 months    0.0751       217.77
# 2      12000        12000     11196.564730   36 months    0.1025       388.62
# 3      22750        22750     21931.621590   36 months    0.1136       748.73
# 4      15500        15500     15500.000000   36 months    0.1645       548.36
#
#    grade emp_length home_ownership  annual_inc verification_status  issue_d  \
# 0      1    6 years           RENT     86000.0        Not Verified        0
# 1      0    4 years           RENT     80000.0     Source Verified        0
# 2      1     1 year           RENT     48645.0        Not Verified        0
# 3      1    5 years           RENT     58600.0        Not Verified        0
# 4      4    2 years       MORTGAGE    415000.0        Not Verified        0
#
#    loan_status             purpose    dti  delinq_2yrs  inq_last_6mths  \
# 0          1.0  debt_consolidation  12.35            0               0
# 1          1.0      major_purchase  14.88            0               0
# 2          1.0  debt_consolidation  13.64            0               0
# 3          1.0  debt_consolidation  24.66            0               1
# 4          1.0         credit_card   0.68            0               2
#
#    open_acc  pub_rec  revol_bal  revol_util  total_acc  initial_list_status  \
# 0        10        0       9871       0.456         23                    0
# 1        10        1       8433       0.413         17                    0
# 2        10        0      13039       0.310         17                    0
# 3         8        0       1449       0.296         37                    0
# 4        11        0      11886       0.563         31                    0
#
#    out_prncp  out_prncp_inv   total_pymnt  total_pymnt_inv  total_rec_prncp  \
# 0          0              0  15161.065730         13440.86          13000.0
# 1          0              0   7838.664792          7582.93           7000.0
# 2          0              0  13922.041770         12966.90          12000.0
# 3          0              0  25428.895730         24460.37          22750.0
# 4          0              0  19418.699580         19418.70          15500.0
#
#    total_rec_int  total_rec_late_fee  recoveries  collection_recovery_fee  \
# 0        2161.07                 0.0         0.0                      0.0
# 1         838.66                 0.0         0.0                      0.0
# 2        1922.04                 0.0         0.0                      0.0
# 3        2678.90                 0.0         0.0                      0.0
# 4        3918.70                 0.0         0.0                      0.0
#
#    last_pymnt_d  last_pymnt_amnt  collections_12_mths_ex_med  policy_code  \
# 0            34          2907.14                           0            1
# 1            36           455.06                           0            1
# 2            33          2701.47                           0            1
# 3            13         14957.35                           0            1
# 4            25          5188.83                           0            1
#
#    acc_now_delinq  chargeoff_within_12_mths  delinq_amnt  \
# 0               0                         0            0
# 1               0                         0            0
# 2               0                         0            0
# 3               0                         0            0
# 4               0                         0            0
#
#    pub_rec_bankruptcies  tax_liens
# 0                   0.0          0
# 1                   1.0          0
# 2                   0.0          0
# 3                   0.0          0
# 4                   0.0          0

# %%
raw_df['issue_d'] = raw_df['issue_d'].astype('category').cat.codes
#raw_df['revol_util'] = raw_df['revol_util'].str.rstrip('%').astype('float') / 100.0

# %%
raw_df['last_pymnt_d'] = raw_df['last_pymnt_d'].astype('category').cat.codes

# %%
raw_df.initial_list_status = 0

# %%
category_vars_int = ['issue_d','last_pymnt_d','initial_list_status','grade']

# %%
raw_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 42317 entries, 0 to 42316
# Data columns (total 41 columns):
# loan_amnt                     42317 non-null int64
# funded_amnt                   42317 non-null int64
# funded_amnt_inv               42317 non-null float64
# term                          42317 non-null object
# int_rate                      42317 non-null float64
# installment                   42317 non-null float64
# grade                         42317 non-null int8
# emp_length                    42317 non-null object
# home_ownership                42317 non-null object
# annual_inc                    42317 non-null float64
# verification_status           42317 non-null object
# issue_d                       42317 non-null int8
# loan_status                   42317 non-null object
# purpose                       42317 non-null object
# dti                           42317 non-null float64
# delinq_2yrs                   42317 non-null int64
# inq_last_6mths                42317 non-null int64
# open_acc                      42317 non-null int64
# pub_rec                       42317 non-null int64
# revol_bal                     42317 non-null int64
# revol_util                    42317 non-null float64
# total_acc                     42317 non-null int64
# initial_list_status           42317 non-null int64
# out_prncp                     42317 non-null int64
# out_prncp_inv                 42317 non-null int64
# total_pymnt                   42317 non-null float64
# total_pymnt_inv               42317 non-null float64
# total_rec_prncp               42317 non-null float64
# total_rec_int                 42317 non-null float64
# total_rec_late_fee            42317 non-null float64
# recoveries                    42317 non-null float64
# collection_recovery_fee       42317 non-null float64
# last_pymnt_d                  42317 non-null int8
# last_pymnt_amnt               42317 non-null float64
# collections_12_mths_ex_med    42317 non-null int64
# policy_code                   42317 non-null int64
# acc_now_delinq                42317 non-null int64
# chargeoff_within_12_mths      42317 non-null int64
# delinq_amnt                   42317 non-null int64
# pub_rec_bankruptcies          42317 non-null float64
# tax_liens                     42317 non-null int64
# dtypes: float64(15), int64(17), int8(3), object(6)
# memory usage: 12.4+ MB

# %%
category = ['purpose', 'verification_status', 'home_ownership', 'emp_length', 'term']

# %%
labels = raw_df['loan_status']

# %%
dic = {
    "Fully Paid" :1,
    "Charged Off":0
}

# %%
raw_df['loan_status'] = raw_df['loan_status'].map(dic)

# %%
raw_df.tail()
# Out:
#        loan_amnt  funded_amnt  funded_amnt_inv        term  int_rate  \
# 42312       2500         2500      2475.000000   36 months    0.0740
# 42313       8000         8000      8000.000000   36 months    0.1148
# 42314      18500        18500     18175.000000   36 months    0.1287
# 42315      12000        12000     11750.000000   36 months    0.1218
# 42316       9925         9925      9814.100582   36 months    0.1148
#
#        installment  grade emp_length home_ownership  annual_inc  \
# 42312        77.65      0    3 years          OTHER    186000.0
# 42313       263.75      1  10+ years           RENT     36000.0
# 42314       622.22      2    3 years           RENT     62004.0
# 42315       399.60      1     1 year            OWN     41004.0
# 42316       327.22      1    4 years       MORTGAGE     45000.0
#
#       verification_status  issue_d  loan_status             purpose    dti  \
# 42312        Not Verified       52          1.0      major_purchase   4.06
# 42313            Verified       52          1.0  debt_consolidation   2.90
# 42314            Verified       52          1.0  debt_consolidation  11.84
# 42315            Verified       52          1.0    home_improvement   5.24
# 42316            Verified       52          1.0               other  12.67
#
#        delinq_2yrs  inq_last_6mths  open_acc  pub_rec  revol_bal  revol_util  \
# 42312            0               1        15        0      14063       0.502
# 42313            0               1         7        0       2980       0.317
# 42314            0               0        14        0       9530       0.460
# 42315            0               2         6        0      10117       0.363
# 42316            1               3        12        0        696       0.027
#
#        total_acc  initial_list_status  out_prncp  out_prncp_inv   total_pymnt  \
# 42312         33                    0          0              0   2746.653811
# 42313         10                    0          0              0   9494.897134
# 42314         40                    0          0              0  21102.058460
# 42315          9                    0          0              0  12241.862120
# 42316         31                    0          0              0  11779.570270
#
#        total_pymnt_inv  total_rec_prncp  total_rec_int  total_rec_late_fee  \
# 42312          2719.19           2500.0         246.65                 0.0
# 42313          9494.90           8000.0        1494.90                 0.0
# 42314         20731.35          18500.0        2602.06                 0.0
# 42315         11986.83          12000.0         241.86                 0.0
# 42316         11637.87           9925.0        1854.57                 0.0
#
#        recoveries  collection_recovery_fee  last_pymnt_d  last_pymnt_amnt  \
# 42312         0.0                      0.0            13          1121.49
# 42313         0.0                      0.0            34           280.33
# 42314         0.0                      0.0            16         11775.21
# 42315         0.0                      0.0           109         11843.99
# 42316         0.0                      0.0            35           346.22
#
#        collections_12_mths_ex_med  policy_code  acc_now_delinq  \
# 42312                           0            1               0
# 42313                           0            1               0
# 42314                           0            1               0
# 42315                           0            1               0
# 42316                           0            1               0
#
#        chargeoff_within_12_mths  delinq_amnt  pub_rec_bankruptcies  tax_liens
# 42312                         0            0                   0.0          0
# 42313                         0            0                   0.0          0
# 42314                         0            0                   0.0          0
# 42315                         0            0                   0.0          0
# 42316                         0            0                   0.0          0

# %%
features = raw_df.drop(columns="loan_status")

# %%
labels = raw_df['loan_status']

# %%
assert features.shape[0] == labels.shape[0]

# %%
features.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 42317 entries, 0 to 42316
# Data columns (total 40 columns):
# loan_amnt                     42317 non-null int64
# funded_amnt                   42317 non-null int64
# funded_amnt_inv               42317 non-null float64
# term                          42317 non-null object
# int_rate                      42317 non-null float64
# installment                   42317 non-null float64
# grade                         42317 non-null int8
# emp_length                    42317 non-null object
# home_ownership                42317 non-null object
# annual_inc                    42317 non-null float64
# verification_status           42317 non-null object
# issue_d                       42317 non-null int8
# purpose                       42317 non-null object
# dti                           42317 non-null float64
# delinq_2yrs                   42317 non-null int64
# inq_last_6mths                42317 non-null int64
# open_acc                      42317 non-null int64
# pub_rec                       42317 non-null int64
# revol_bal                     42317 non-null int64
# revol_util                    42317 non-null float64
# total_acc                     42317 non-null int64
# initial_list_status           42317 non-null int64
# out_prncp                     42317 non-null int64
# out_prncp_inv                 42317 non-null int64
# total_pymnt                   42317 non-null float64
# total_pymnt_inv               42317 non-null float64
# total_rec_prncp               42317 non-null float64
# total_rec_int                 42317 non-null float64
# total_rec_late_fee            42317 non-null float64
# recoveries                    42317 non-null float64
# collection_recovery_fee       42317 non-null float64
# last_pymnt_d                  42317 non-null int8
# last_pymnt_amnt               42317 non-null float64
# collections_12_mths_ex_med    42317 non-null int64
# policy_code                   42317 non-null int64
# acc_now_delinq                42317 non-null int64
# chargeoff_within_12_mths      42317 non-null int64
# delinq_amnt                   42317 non-null int64
# pub_rec_bankruptcies          42317 non-null float64
# tax_liens                     42317 non-null int64
# dtypes: float64(15), int64(17), int8(3), object(5)
# memory usage: 12.1+ MB

# %%
features_ohe = pd.get_dummies(features)

# %%
features_ohe = features_ohe.drop(columns="total_rec_prncp")

# %%
def split_vals(a,n): return a[:n].copy(), a[n:].copy()

# %%
X_train , X_valid = split_vals(features_ohe, 20000)
y_train , y_valid = split_vals(labels, 20000)
y_valid = np.ravel(y_valid)
y_train = np.ravel(y_train)
y_valid.shape
# Out:
# (22317,)

# %%
X_train.head()
# Out:
#    loan_amnt  funded_amnt  funded_amnt_inv  int_rate  installment
 'open_acc', 'pub_rec', 'revol_bal', 'revol_util',
       'total_acc','out_prncp', 'out_prncp_inv',
       'total_pymnt', 'total_pymnt_inv', 'total_rec_int',
       'total_rec_late_fee','last_pymnt_amnt', 'collections_12_mths_ex_med']

# %%
## Default model
m=RandomForestClassifier(n_estimators=200)


# %time m.fit(X_train, y_train)
# Out:
# Wall time: 7.51 s
# RandomForestClassifier(bootstrap=True, class_weight=None, criterion='gini',
#                        max_depth=None, max_features='auto', max_leaf_nodes=None,
#                        min_impurity_decrease=0.0, min_impurity_split=None,
#                        min_samples_leaf=1, min_samples_split=2,
#                        min_weight_fraction_leaf=0.0, n_estimators=200,
#                        n_jobs=None, oob_score=False, random_state=None,
#                        verbose=0, warm_start=False)

# %%
print("Accuracy:",metrics.accuracy_score(y_valid, m.predict(X_valid)))
# Out:
# Accuracy: 0.9363265671909307

# %%
feat_imp = pd.DataFrame({"Columns": X_train.columns, 
                         "importance": m.feature_importances_})

# %%
feat_imp.sort_values("importance",ascending=False)
# Out:
#                              Columns  importance
# 20                   total_pymnt_inv    0.146815
# 19                       total_pymnt    0.145039
# 24                   last_pymnt_amnt    0.128092
# 23                      last_pymnt_d    0.091678
# 1                        funded_amnt    0.059825
# 2                    funded_amnt_inv    0.059024
# 4                        installment    0.051722
# 0                          loan_amnt    0.044432
# 21                     total_rec_int    0.041127
# 3                           int_rate    0.026800
# 22                total_rec_late_fee    0.020820
# 14                        revol_util    0.016173
# 8                                dti    0.015371
# 6                         annual_inc    0.015077
# 13                         revol_bal    0.014241
# 5                              grade    0.012896
# 15                         total_acc    0.011924
# 32                   term_ 36 months    0.011784
# 7                            issue_d    0.011658
# 33                   term_ 60 months    0.010519
# 11                          open_acc    0.010046
# 10                    inq_last_6mths    0.007852
# 55        purpose_debt_consolidation    0.002807
# 64            purpose_small_business    0.002423
# 9                        delinq_2yrs    0.002305
# 52      verification_status_Verified    0.002275
# 50  verification_status_Not Verified    0.002258
# 35              emp_length_10+ years    0.002137
# 45           home_ownership_MORTGAGE    0.002114
# 49               home_ownership_RENT    0.002068
# ..                               ...         ...
# 62                     purpose_other    0.001338
# 44               emp_length_< 1 year    0.001327
# 36                emp_length_2 years    0.001322
# 39                emp_length_5 years    0.001319
# 48                home_ownership_OWN    0.001294
# 38                emp_length_4 years    0.001265
# 40                emp_length_6 years    0.001142
# 57          purpose_home_improvement    0.001092
# 42                emp_length_8 years    0.000937
# 43                emp_length_9 years    0.000918
# 59            purpose_major_purchase    0.000899
# 53                       purpose_car    0.000760
# 61                    purpose_moving    0.000530
# 65                  purpose_vacation    0.000511
# 60                   purpose_medical    0.000508
# 56               purpose_educational    0.000445
# 66                   purpose_wedding    0.000439
# 58                     purpose_house    0.000434
# 63          purpose_renewable_energy    0.000347
# 47              home_ownership_OTHER    0.000242
# 46               home_ownership_NONE    0.000000
# 17                         out_prncp    0.000000
# 31                         tax_liens    0.000000
# 29                       delinq_amnt    0.000000
# 28          chargeoff_within_12_mths    0.000000
# 27                    acc_now_delinq    0.000000
# 26                       policy_code    0.000000
# 25        collections_12_mths_ex_med    0.000000
# 16               initial_list_status    0.000000
# 18                     out_prncp_inv    0.000000
#
# [67 rows x 2 columns]

# %%
X_train.to_csv('processed/training_features.csv')
X_valid.to_csv('processed/testing_features.csv')
pd.DataFrame(y_train).to_csv('processed/training_labels.csv')
pd.DataFrame(y_valid).to_csv('processed/testing_labels.csv')
